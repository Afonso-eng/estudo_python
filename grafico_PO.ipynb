# %%
# GRÁFICO POO

# %%
import matplotlib.pyplot as plt
meses=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
vendas=[1500,1727,1350,1775,1052,1200,1300,1200,1100,1400,1500,1800]

fig, ax=plt.subplots()
ax.plot(meses,vendas,color='darkblue')
ax.set_xlabel('Meses')
ax.set_ylabel('Vendas')
ax.set_title('Vendas por mês')
plt.box(False)
plt.show()

# %% [markdown]
# # grafico de barras

# %%
import matplotlib.pyplot as plt
prdutos =['iphone','samsung','xiaomi','motorola']   
vendas = [15000,12000,14000,17000]
fig, ax = plt.subplots()
ax.bar(prdutos,vendas)
ax.set_title('Vendas de celulares')
ax.set_xlabel('Produtos')
ax.set_ylabel('Vendas')
plt.show()

# %% [markdown]
# # GRÁFICO DE PIZZA

# %%
import matplotlib.pyplot as plt
categorias = ['Python', 'JavaScript', 'Java', 'C#', 'PHP']
quatidades = [25, 20, 15, 20, 10]
destacados = [True, False, False, True, False]
fig, ax = plt.subplots()
ax.pie(quatidades, labels=categorias, autopct='%1.1f%%', explode=[0.1, 0, 0, 0, 0])
plt.show()

# %%
anos=[2015,2016,2017,2018,2019,2020,2021]
vendas_online=[100,200,300,400,500,600,700]
vendas_loja=[10,20,30,40,50,60,70]

fig, ax = plt.subplots()
ax.bar(anos,vendas_loja, label='Vendas Loja',bottom=vendas_online)
ax.bar(anos,vendas_online, label='Vendas Online')
ax.set_title('Vendas Online e Loja')
ax.set_xlabel('Anos')
ax.set_ylabel('Vendas')
plt.legend()
plt.show()

# %%
# criar um grafico de climograma
import matplotlib.pyplot as plt
meses=['JAN','FEV','MAR','ABR','MAI','JUN','JUL','AGO','SET','OUT','NOV','DEZ']
temp_media=[25.5,21.5,20.5,15.5,16.5,13.5,14.5,15.5,19.5,25.5,21.5,22.5]
precipitacao=[150,120,100,80,60,40,20,20,40,60,80,100]

fig, ax1 = plt.subplots(figsize=(8,5))


cor_temperatura='tab:red'
cor_precipitacao='tab:blue'

ax1.bar(meses,precipitacao,color=cor_precipitacao,label='precipitação')
ax1.set_ylabel('precipitação em MM',color=cor_precipitacao)
ax1.tick_params(axis='y',labelcolor=cor_precipitacao)





ax2 = ax1.twinx()
ax2.plot(meses,temp_media,color=cor_temperatura,linewidth=2,marker='o',label='temperatura')
ax2.set_ylabel('temperatura em °C',color=cor_temperatura)
ax2.tick_params(axis='y',labelcolor=cor_temperatura)



ax1.set_title('Climograma')
#adicionando legenda

fig.legend(loc="upper left", bbox_to_anchor=(0.4,1), bbox_transform=ax1.transAxes)

plt.show()
